# %% [markdown]
# # Import Modules // Set up API Key & Query

# %%
import json
import re
import urllib.request
from pytube import YouTube
import pandas as pd

# %%
api_key = "AIzaSyDil2JJ6M5UNgs07giVsBJ0myAaD2BNiKg"

# %%
from apiclient.discovery import build

# %%
youtube = build('youtube', 'v3', developerKey = api_key)

# %%
type(youtube)
# Out:
# googleapiclient.discovery.Resource

# %%
req = youtube.search().list(q='soft glam', part='snippet', type='video', maxResults=50)

# %%
type(req)
# Out:
# googleapiclient.http.HttpRequest

# %%
res = req.execute()

# %%
res
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': '"nxOHAKTVB7baOKsQgTtJIyGxcs8/7iXflvaX907lmEW6p7JwPfbRo-g"',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'US',
#  'pageInfo': {'totalResults': 1000000, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': '"nxOHAKTVB7baOKsQgTtJIyGxcs8/Imh-vo9oVb6hKUvUR-G6U9qMR9I"',
#    'id': {'kind': 'youtube#video', 'videoId': 'vN1zDEtzd0E'},
#    'snippet': {'publishedAt': '2020-01-08T22:58:12.000Z',
#     'channelId': 'UCKRzxQcorbRkk7Ofr5T0-lw',
#     'title': '2020 SOFT GLAM TUTORIAL *TRENDY*',
#     'description': "Hey flowers!! In today's make up tutorial I will be showing you how to achieve the perfect Soft Glam Natural Makeup Look! I'm giving away cash so make sure to ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vN1zDEtzd0E/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/vN1zDEtzd0E/mqdefault.jpg',
#       'width': 320,
# ...

# %%
for item in res['items']:
    print(item['snippet']['title'])
# Out:
# 2020 SOFT GLAM TUTORIAL *TRENDY*
# What The Hell is SOFT GLAM MAKEUP?!
# how I soft glam
# GLAM for NOTHING! lol 🦊🤧 soft glam x foxy eye makeup tutorial
# SOFT GLAM MAKEUP TUTORIAL 2020
# TWITTER! SOFT! GLAM! that&#39;s it, that&#39;s the tweet.
# FAVOURITE EVERYDAY SOFT GLAM MAKEUP!
# Everyday Makeup Routine (Soft Glam) | Jordyn Woods
# Soft Glam Makeup Tutorial I Aylin Melisa
# SOFT GLAM GRWM | Get ready with me to go absolutely nowhere | Naomi Nyara
# *Soft Glam* Get Cute With Me! ft Beauty Forever Hair
# FULL COVERAGE SOFT GLAM SMOKEY EYE!
# SOFT GLAM 10 MINUTE MAKEUP TUTORIAL
# Doing My Makeup Like Beyonce&#39;s! (Literally A Soft Glam Look Lmao)
# GET READY WITH ME! DATE NIGHT, SOFT GLAM
# SOFT GLAM: MAQUILLAJE PARA EL DIA |Karomakeup|
# Soft Glam, But Make It Drugstore...? | Jackie Aina
# MY SIMPLE EVERYDAY MAKEUP ROUTINE💖 ( EASY SOFT GLAM LOOK ) || ZULEMA ZARATE
# Everyday SOFT GLAM Makeup Tutorial
# ...

# %%
len(res['items'])
type(res)
# Out:
# dict

# %%
res.keys()
# Out:
# dict_keys(['kind', 'etag', 'nextPageToken', 'regionCode', 'pageInfo', 'items'])

# %%
res['pageInfo']
# Out:
# {'totalResults': 1000000, 'resultsPerPage': 50}

# %%
res['items']
# Out:
# [{'kind': 'youtube#searchResult',
#   'etag': '"nxOHAKTVB7baOKsQgTtJIyGxcs8/Imh-vo9oVb6hKUvUR-G6U9qMR9I"',
#   'id': {'kind': 'youtube#video', 'videoId': 'vN1zDEtzd0E'},
#   'snippet': {'publishedAt': '2020-01-08T22:58:12.000Z',
#    'channelId': 'UCKRzxQcorbRkk7Ofr5T0-lw',
#    'title': '2020 SOFT GLAM TUTORIAL *TRENDY*',
#    'description': "Hey flowers!! In today's make up tutorial I will be showing you how to achieve the perfect Soft Glam Natural Makeup Look! I'm giving away cash so make sure to ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vN1zDEtzd0E/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/vN1zDEtzd0E/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/vN1zDEtzd0E/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Daisy Marquez',
#    'liveBroadcastContent': 'none'}},
#  {'kind': 'youtube#searchResult',
# ...

# %%
item1 = res['items'][0]
type(item1)
# Out:
# dict

# %% [markdown]
# # Clean up data by targetting keys

# %%
res['items'][0].keys()
# Out:
# dict_keys(['kind', 'etag', 'id', 'snippet'])

# %%
vid = res['items'][0]['id']
vid['videoId']
# Out:
# 'vN1zDEtzd0E'

# %%
res['items'][0]['snippet'].keys()
# Out:
# dict_keys(['publishedAt', 'channelId', 'title', 'description', 'thumbnails', 'channelTitle', 'liveBroadcastContent'])

# %%
df = pd.DataFrame(columns = ["title", "description", "thumbnail", "videoId"])
df
# Out:
# Empty DataFrame
# Columns: [title, description, thumbnail, videoId]
# Index: []

# %%
def Convert(string):
    li = list(string.split(" "))
    return(li)

# %%
for index in range(0,50):
    for i in res['items'][index]:
        title = (res['items'][index]['id']['videoId'])
        print(title)
# Out:
# vN1zDEtzd0E
# vN1zDEtzd0E
# vN1zDEtzd0E
# vN1zDEtzd0E
# 7mG6SDhiR1A
# 7mG6SDhiR1A
# 7mG6SDhiR1A
# 7mG6SDhiR1A
# 9IcXDa797Xc
# 9IcXDa797Xc
# 9IcXDa797Xc
# 9IcXDa797Xc
# CjeLWb_bs5s
# CjeLWb_bs5s
# CjeLWb_bs5s
# CjeLWb_bs5s
# ZWmBvDIr7H0
# ZWmBvDIr7H0
# ZWmBvDIr7H0
# ZWmBvDIr7H0
# Pa1u0fRoxJE
# Pa1u0fRoxJE
# Pa1u0fRoxJE
# Pa1u0fRoxJE
# diEBrfoSIwY
# diEBrfoSIwY
# diEBrfoSIwY
# diEBrfoSIwY
# YNUP6MPj1pQ
# YNUP6MPj1pQ
# YNUP6MPj1pQ
# YNUP6MPj1pQ
# cNLhZ9MOC7s
# cNLhZ9MOC7s
# cNLhZ9MOC7s
# cNLhZ9MOC7s
# h2OllmyAlK4
# h2OllmyAlK4
# h2OllmyAlK4
# h2OllmyAlK4
# njGRDm6CkJM
# njGRDm6CkJM
# njGRDm6CkJM
# njGRDm6CkJM
# JEfFhllSod0
# JEfFhllSod0
# JEfFhllSod0
# JEfFhllSod0
# BBCFD60mgL4
# BBCFD60mgL4
# BBCFD60mgL4
# BBCFD60mgL4
# bFnH1E2F-DI
# bFnH1E2F-DI
# bFnH1E2F-DI
# bFnH1E2F-DI
# 59VGepflKJM
# 59VGepflKJM
# 59VGepflKJM
# 59VGepflKJM
# sbuoCRgOn8w
# sbuoCRgOn8w
# sbuoCRgOn8w
# sbuoCRgOn8w
# KBqVStRaE_U
# KBqVStRaE_U
# KBqVStRaE_U
# KBqVStRaE_U
# 4EwUv0y3cwQ
# 4EwUv0y3cwQ
# 4EwUv0y3cwQ
# ...

# %%
thumbnails = []
index = 0
for index in range(0,50):
    for i in res['items'][index]:
        title = (res['items'][index]['snippet']['description'])
        print(title)
# Out:
# Hey flowers!! In today's make up tutorial I will be showing you how to achieve the perfect Soft Glam Natural Makeup Look! I'm giving away cash so make sure to ...
# Hey flowers!! In today's make up tutorial I will be showing you how to achieve the perfect Soft Glam Natural Makeup Look! I'm giving away cash so make sure to ...
# Hey flowers!! In today's make up tutorial I will be showing you how to achieve the perfect Soft Glam Natural Makeup Look! I'm giving away cash so make sure to ...
# Hey flowers!! In today's make up tutorial I will be showing you how to achieve the perfect Soft Glam Natural Makeup Look! I'm giving away cash so make sure to ...
# This is soft glam makeup snitches!!! Enjoy! This video is done in partnership with VESCA https://bit.ly/2LYnODs P R O D U C T S  M E N T I O N E D: ...
# This is soft glam makeup snitches!!! Enjoy! This video is done in partnership with VESCA https://bit.ly/2LYnODs P R O D U C T S  M E N T I O N E D: ...
# ...

# %%
title
# Out:
# 'ABH✨: палетка SOFT GLAM + хайлайтер Amrezy'

# %%
index = 0

for index in range(0,50):
    for i in res['items'][index]:
        snippets = (res['items'][index]['snippet']['thumbnails'])
#         print(snippets['default']['url'])
        links = snippets['default']['url']
        thumbnails = images.append(links)
        print(links)
#         urllib.request.urlretrieve(links)
# Out:
# https://i.ytimg.com/vi/vN1zDEtzd0E/default.jpg
# https://i.ytimg.com/vi/vN1zDEtzd0E/default.jpg
# https://i.ytimg.com/vi/vN1zDEtzd0E/default.jpg
# https://i.ytimg.com/vi/vN1zDEtzd0E/default.jpg
# https://i.ytimg.com/vi/7mG6SDhiR1A/default.jpg
# https://i.ytimg.com/vi/7mG6SDhiR1A/default.jpg
# https://i.ytimg.com/vi/7mG6SDhiR1A/default.jpg
# https://i.ytimg.com/vi/7mG6SDhiR1A/default.jpg
# https://i.ytimg.com/vi/9IcXDa797Xc/default.jpg
# https://i.ytimg.com/vi/9IcXDa797Xc/default.jpg
# https://i.ytimg.com/vi/9IcXDa797Xc/default.jpg
# https://i.ytimg.com/vi/9IcXDa797Xc/default.jpg
# https://i.ytimg.com/vi/CjeLWb_bs5s/default.jpg
# https://i.ytimg.com/vi/CjeLWb_bs5s/default.jpg
# https://i.ytimg.com/vi/CjeLWb_bs5s/default.jpg
# https://i.ytimg.com/vi/CjeLWb_bs5s/default.jpg
# https://i.ytimg.com/vi/ZWmBvDIr7H0/default.jpg
# https://i.ytimg.com/vi/ZWmBvDIr7H0/default.jpg
# https://i.ytimg.com/vi/ZWmBvDIr7H0/default.jpg
# https://i.ytimg.com/vi/ZWmBvDIr7H0/default.jpg
# ...

# %%
# Out:
# 'https://i.ytimg.com/vi/ltqDjZhsOQo/default.jpg'

# %%
index = 0
for index in range(0,50):
    for i in res['items'][index]:
        snippets = (res['items'][index]['snippet']['description'])
        print(snippets)
# Out:
# Hey flowers!! In today's make up tutorial I will be showing you how to achieve the perfect Soft Glam Natural Makeup Look! I'm giving away cash so make sure to ...
# Hey flowers!! In today's make up tutorial I will be showing you how to achieve the perfect Soft Glam Natural Makeup Look! I'm giving away cash so make sure to ...
# Hey flowers!! In today's make up tutorial I will be showing you how to achieve the perfect Soft Glam Natural Makeup Look! I'm giving away cash so make sure to ...
# Hey flowers!! In today's make up tutorial I will be showing you how to achieve the perfect Soft Glam Natural Makeup Look! I'm giving away cash so make sure to ...
# This is soft glam makeup snitches!!! Enjoy! This video is done in partnership with VESCA https://bit.ly/2LYnODs P R O D U C T S  M E N T I O N E D: ...
# This is soft glam makeup snitches!!! Enjoy! This video is done in partnership with VESCA https://bit.ly/2LYnODs P R O D U C T S  M E N T I O N E D: ...
# ...

# %%
print(snippets['default']['url'])
# Out:
# https://i.ytimg.com/vi/ltqDjZhsOQo/default.jpg

# %%
snip = pd.DataFrame(titleList)

# %%
type(snip)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
#  ## Started to update to Pandas and explore data structure of video.list
#
# This will be revisited after first iteration of feature extraction. Data clean up results were imported into csv manually. Metatag data needs to be transformed into viable features for modeling and requires further data analysis

# %%
df = pd.DataFrame(snip, columns = ["title", "description", "thumbnail", "videoId"])
df
# Out:
#    title  description  thumbnail  videoId
# 0    NaN          NaN        NaN      NaN
# 1    NaN          NaN        NaN      NaN
# 2    NaN          NaN        NaN      NaN
# 3    NaN          NaN        NaN      NaN
# 4    NaN          NaN        NaN      NaN
# 5    NaN          NaN        NaN      NaN
# 6    NaN          NaN        NaN      NaN

# %%
# for item in res['items']:
#      print((item['snippet']['id']['kind']))
url = youtube.videos().list(part='snippet', id='CjeLWb_bs5s')

# %%
url.execute()
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': '"nxOHAKTVB7baOKsQgTtJIyGxcs8/mKdSvrAtYdkuewCPao3y2QXNhoc"',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1},
#  'items': [{'kind': 'youtube#video',
#    'etag': '"nxOHAKTVB7baOKsQgTtJIyGxcs8/oMFLqY8kk88mIetaHDmriTyBXvw"',
#    'id': 'CjeLWb_bs5s',
#    'snippet': {'publishedAt': '2020-04-20T17:00:04.000Z',
#     'channelId': 'UCrvtaFqvZCljQKKU6T6Z7cg',
#     'title': 'GLAM for NOTHING! lol 🦊🤧 soft glam x foxy eye makeup tutorial',
# ...

# %% [markdown]
# # Download Images into Folder
# Step 1 of Feature extraction: Read in .csv file & download images into a folder

# %%
def url_to_jpg(i, urls, filepath):
    filename = 'image-{}.jpg'.format
    fullpath = '{}{}'.format(filepath,filename)
    urllib.request.urlretrieve(url, fullpath)
    
    print('{} saved.'.format(filename))
    return None

# %%
fn = './data/videoList.csv'
fp = './images'

# %%
uList = []
urls = pd.read_csv(fn)
type(urls)
uList.append(urls)
type(uList)
# Out:
# list

# %%
  urllib.request.urlretrieve(uList)
# Out:
# ---------------------------------------------------------------------------
# URLError                                  Traceback (most recent call last)
# <ipython-input-388-f0c82ed57e9f> in <module>
# ----> 1 urllib.request.urlretrieve(uList)
#
# /usr/local/Cellar/python/3.7.4_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     245     url_type, path = splittype(url)
#     246
# --> 247     with contextlib.closing(urlopen(url, data)) as fp:
#     248         headers = fp.info()
#     249
#
# /usr/local/Cellar/python/3.7.4_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-378-d60e35b05b41> in <module>
# ----> 1 urllib.request.urlretrieve(uList[0])
#
# /usr/local/Cellar/python/3.7.4_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     245     url_type, path = splittype(url)
#     246
# --> 247     with contextlib.closing(urlopen(url, data)) as fp:
#     248         headers = fp.info()
#     249
#
# /usr/local/Cellar/python/3.7.4_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ...

# %%
row_iterator = urls.iterrows.next()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-333-cc38f816d318> in <module>
# ----> 1 row_iterator = urls.iterrows.next()
#
# AttributeError: 'function' object has no attribute 'next'

# %%
for index, row in urls.iterrows():
    uList = str(urls)
    file_names = uList.split(' ')[-1]
    print(file_names)
    
#     url_to_jpg(i, urls,fp)
# Out:
# https://i.ytimg.com/vi/ltqDjZhsOQo/default.jpg
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-344-dbfb6ca87fa6> in <module>
#       3     file_names = uList.split(' ')[-1]
#       4     print(file_names)
# ----> 5     url_to_jpg(i, file_names, fp)
#
# <ipython-input-320-42510011426f> in url_to_jpg(i, urls, filepath)
#       2     filename = 'image-{}.jpg'.format
#       3     fullpath = '{}{}'.format(filepath,filename)
# ----> 4     urllib.request.urlretrieve(url, fullpath)
#       5
#       6     print('{} saved.'.format(filename))
#
# /usr/local/Cellar/python/3.7.4_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     243     data file as well as the resulting HTTPMessage object.
#     244     """
# --> 245     url_type, path = splittype(url)
#     246
# ...

# %%
# Out:
#     https://i.ytimg.com/vi/vN1zDEtzd0E/default.jpg  thumbnail
# 0                                              NaN        NaN
# 1                                              NaN        NaN
# 2                                              NaN        NaN
# 3                                              NaN        NaN
# 4                                              NaN        NaN
# ..                                             ...        ...
# 44  https://i.ytimg.com/vi/Co7I9wY7A88/default.jpg        NaN
# 45  https://i.ytimg.com/vi/ZsZQevbRB2M/default.jpg        NaN
# 46  https://i.ytimg.com/vi/Wk5w0e0XTlQ/default.jpg        NaN
# 47  https://i.ytimg.com/vi/85d52w1QdCw/default.jpg        NaN
# 48  https://i.ytimg.com/vi/ltqDjZhsOQo/default.jpg        NaN
#
# [98 rows x 2 columns]

# %%
# Out:
# pandas.core.frame.DataFrame
